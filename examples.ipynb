# %%
import genetic_toolbox as gen
import matplotlib.pyplot as plt
import numpy as np

# %%
# Task one.
# For testfn3b function implement hill-climbing algorithm
x = np.linspace(-800, 800, 1000)
y = gen.testfn3b(x)


plt.plot(x, y)
plt.grid()
